# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/dl_project/code
# Out:
# /content/gdrive/My Drive/dl_project/code

# %%
import os
import torch 
from optimizer import get_optimizer
from inception_initial import Inception_initial
from inception_pretrain import Inception_pretrain
from vgg16_initial import Vgg16_initial
from vgg16_pretrain import Vgg16_pretrain
from resnet_initial import Resnet_initial
from resnet_pretrain import Resnet_pretrain
from alexnet_initial import AlexNet_Initial
from alexnet_transfer import AlexNet_Transfer
from metrics import Metrics

# %%
data_path = '../data_sub/'
model_path = '../model_save/'
print(os.listdir(data_path))
print(os.listdir(model_path))
# Out:
# ['train', 'test']
# ['.placeholder', 'vgg16_pretrain_net.pt', 'vgg16_initial_net.pt', 'resnet34_initial_net.pt', 'resnet34_pretrain_net.pt', 'inception_initial_net.pt', 'inception_pretrain_net.pt', 'alexnet_initial.pt', 'alexnet_transfer.pt']

# %% [markdown]
# ## Inception Initial

# %%
inception_initial_net = Inception_initial()

# %%
metrics=Metrics(model=inception_initial_net, model_dir=model_path, model_name="inception_initial_net.pt", data_dir=data_path, batch_size=128, shuffle=False)

# %%
metrics.metrics()
# Out:
# Accuracy:0.9593, Top5Accuracy:0.9962
# precision: 0.9592869996654505
# recall: 0.9590458015349436
# fscore: 0.9587112873957381

# %% [markdown]
# ## Inception Pretrain

# %%
inception_pretrain_net = Inception_pretrain()

# %%
metrics=Metrics(model=inception_pretrain_net, model_dir=model_path, model_name="inception_pretrain_net.pt", data_dir=data_path, batch_size=128, shuffle=False)

# %%
metrics.metrics()
# Out:
# Accuracy:0.7875, Top5Accuracy:0.9733
# precision: 0.794118801274163
# recall: 0.7815147519011717
# fscore: 0.7777132000694571

# %% [markdown]
# ## Vgg initial

# %%
vgg16_initial_net = Vgg16_initial()

# %%
metrics=Metrics(model=vgg16_initial_net, model_dir=model_path, model_name="vgg16_initial_net.pt", data_dir=data_path, batch_size=128, shuffle=False)

# %%
metrics.metrics()
# Out:
# Accuracy:0.9885, Top5Accuracy:0.9987
# precision: 0.9883467144247309
# recall: 0.9883943390503381
# fscore: 0.9883183101747031

# %% [markdown]
# ## Vgg Pretrain

# %%
vgg16_pretrain_net = Vgg16_pretrain()
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16_bn-6c64b313.pth" to /root/.cache/torch/hub/checkpoints/vgg16_bn-6c64b313.pth
# ...

# %%
metrics=Metrics(model=vgg16_pretrain_net, model_dir=model_path, model_name="vgg16_pretrain_net.pt", data_dir=data_path, batch_size=128, shuffle=False)

# %%
metrics.metrics()
# Out:
# Accuracy:0.9860, Top5Accuracy:0.9994
# precision: 0.9864363294795455
# recall: 0.9854460427845693
# fscore: 0.9858479296603273

# %% [markdown]
# ## Resnet34 Initial

# %%
resnet34_initial_net = Resnet_initial()

# %%
metrics=Metrics(model=resnet34_initial_net, model_dir=model_path, model_name="resnet34_initial_net.pt", data_dir=data_path, batch_size=128, shuffle=False)

# %%
metrics.metrics()
# Out:
# Accuracy:0.9873, Top5Accuracy:0.9975
# precision: 0.9877002570246518
# recall: 0.9866513011379847
# fscore: 0.9870731583023022

# %% [markdown]
# ## Resnet 34 Pretrain

# %%
resnet34_pretrain_net = Resnet_pretrain()

# %%
metrics=Metrics(model=resnet34_pretrain_net, model_dir=model_path, model_name="resnet34_pretrain_net.pt", data_dir=data_path, batch_size=128, shuffle=False)

# %%
metrics.metrics()
# Out:
# Accuracy:0.9294, Top5Accuracy:0.9943
# precision: 0.9315407264785771
# recall: 0.9299146161967489
# fscore: 0.9292368984157482

# %% [markdown]
# ## Alexnet Pretrain

# %%
alexnet_transfer=AlexNet_Transfer()
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /Users/shuyuding/.cache/torch/hub/checkpoints/alexnet-owt-4df8aa71.pth
# ...

# %%
metrics=Metrics(model=alexnet_transfer, model_dir=model_path, model_name="alexnet_transfer.pt", data_dir=data_path, batch_size=128, shuffle=False)

# %%
metrics.metrics()
# Out:
# Accuracy:0.9695, Top5Accuracy:0.9981
# precision: 0.9704175831249566
# recall: 0.96876149432782
# fscore: 0.9693480379299102

# %% [markdown]
# ## Alexnet Initial

# %%
alexnet_initial=AlexNet_Initial()

# %%
metrics=Metrics(model=alexnet_initial, model_dir=model_path, model_name="alexnet_initial.pt", data_dir=data_path, batch_size=128, shuffle=False)

# %%
metrics.metrics()
# Out:
# Accuracy:0.9523, Top5Accuracy:0.9955
# precision: 0.9524333603806147
# recall: 0.9502222165264227
# fscore: 0.9505060913215715
